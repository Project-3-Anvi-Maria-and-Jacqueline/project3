# %%
import requests
import pandas as pd
import os
from dotenv import load_dotenv
import json
import numpy as np

# %%
load_dotenv()
opensea_api_key = os.getenv('OPENSEA_API_KEY')

# %% [markdown]
# # Data for Context and Analysis

# %% [markdown]
# ### Collection Stats

# %%
url = "https://api.opensea.io/api/v2/collections/pudgypenguins/stats"

headers = {
    "accept": "application/json",
    "x-api-key": opensea_api_key
}

response = requests.get(url, headers=headers)

collection_stats_response_json = response.json()

collection_totals_dict = collection_stats_response_json["total"]

# I had to set this index because there is not index and it was causing an error
# I used ChatGPT to debug this issue
collection_totals_df = pd.DataFrame(collection_totals_dict, index=[0])

collection_totals_df
# Out:
#           volume  sales  ...  floor_price  floor_price_symbol
# 0  345810.109458  78949  ...    11.557789                 ETH
#
# [1 rows x 7 columns]

# %% [markdown]
# ## Trait Counts

# %%
url = "https://api.opensea.io/api/v2/traits/pudgypenguins"

headers = {
    "accept": "application/json",
    "x-api-key": opensea_api_key
}

response = requests.get(url, headers=headers)

# Formatting as json
traits_json = response.json()

# get the "counts" and not "categories" key
traits_json = traits_json.get("counts", [])

# preview
traits_json
# Out:
# {'Background': {'Beige': 1152,
#   'Blue': 1587,
#   'Mint': 1389,
#   'Red': 755,
#   'Tangerine': 1135,
#   'Yellow': 873,
#   'Pink': 710,
#   'Purple': 1282,
#   'On The Beach': 1,
#   'Supermarket': 1,
#   'Green': 1,
#   'Trick Or Treating': 1,
#   'Underwater': 1},
#  'Skin': {'Light Gray': 1189,
#   'Mint': 423,
#   'Maroon': 731,
#   'Normal': 2649,
#   'Leopard Pink': 89,
#   'Dark Gray': 1329,
#   'Baby Pink': 623,
#   'Cream': 646,
#   'Olive Green': 705,
#   'Red': 344,
#   'Gold': 44,
#   'Leopard Gray': 89,
#   'Ice': 22,
#   'Navy Blue': 4,
#   'Black': 1},
#  'Body': {'Vote 4 Pudgy': 203,
#   'Kimono Blue': 108,
#   'Scarf Blue': 237,
#   'Shirt Blue': 290,
#   'Fish Lover': 70,
#   'Turtleneck Grey': 210,
#   'Lei Pink': 168,
#   'Bow Tie Blue': 154,
#   'Tank Top Yellow': 193,
#   'Puffer Orange': 158,
#   'Huddle Shirt': 228,
#   'Kimono Brown': 268,
#   'Lei Assorted': 76,
#   'Bronze Medal': 193,
#   'Gold Medal': 58,
#   'Heart': 102,
#   'Turtleneck Green': 254,
#   'Scarf Pink': 177,
#   'Surfboard Necklace': 166,
#   'Swordman': 62,
#   'Christmas Sweater Red': 89,
#   'Bath Robe': 246,
#   'Turtleneck Blue': 238,
#   'Hoodie Black': 183,
#   'Silver Medal': 141,
#   'Puffer Green': 167,
#   'Shirt Red': 259,
#   'Kimono Orange': 115,
#   'Christmas Lights': 131,
#   'Turtleneck Pink': 182,
#   'Suit Blue': 89,
#   'Bow Tie Pink': 172,
#   'Tribal Necklace': 115,
#   'Overalls': 171,
#   'Bow Tie Black': 193,
#   'Scarf Green': 250,
#   'Lei Blue': 180,
#   'Kimono White': 89,
#   'Christmas Sweater Blue': 89,
#   'Kimono Red': 169,
#   'Tank Top Blue': 202,
#   'Puffer Blue': 158,
#   'Kimono Gold': 44,
#   'Biker Jacket': 67,
#   'Apron': 199,
#   'Lei Purple': 186,
#   'Lab Coat': 227,
#   'Shark Tooth Necklace': 88,
#   'Hawaiian Shirt': 171,
#   'Suit Red': 78,
#   'Ice Coat': 123,
#   'Kimono Pink': 89,
#   'Hoodie Pink': 162,
#   'Big P': 71,
#   'Kimono Abstract': 53,
#   'Crop Top': 89,
#   'Kimono Ice': 22,
#   'Pudgy Man': 44,
#   'Pineapple Suit': 1,
#   'Poncho': 167,
#   'Banana Suit': 1,
#   'Mirrored': 1,
#   'Pillow Case': 1,
#   'Shark Suit': 1},
#  'Face': {'Winking': 961,
#   'Star Glasses': 265,
#   'Normal': 864,
#   'Cute': 588,
#   'Beard': 320,
#   'Hero Mask Red': 71,
#   'Scar': 274,
#   'Blushing': 932,
#   'Eyepatch': 426,
#   'Clout Goggles': 342,
#   'Squad': 445,
#   'Circle Glasses': 768,
#   'Goggles': 191,
#   'Aviator': 341,
#   'Villain Mask': 89,
#   'Cross Eyed': 417,
#   'Football': 238,
#   'Mustache': 169,
#   'Cucumbers': 269,
#   'Monocle': 496,
#   'Handlebar Bear': 259,
#   'Scouter': 67,
#   'Hero Mask Blue': 71,
#   'Star Struck': 22,
#   'Mirrored': 1,
#   'Pillow Case': 1,
#   'Agitated': 1},
#  'Head': {'Backwards Hat Blue': 173,
#   'Bucket Hat Tan': 219,
#   'Santa Hat': 208,
#   'Durag Blue': 252,
#   'Backwards Hat Red': 294,
#   'Durag Red': 174,
#   'None': 250,
#   'Ninja Headband': 89,
#   'Afro With Pick': 257,
#   'Bucket Hat Green': 349,
#   'Flat Cap Black': 247,
#   'Flat Cap Blue': 355,
#   'Beanie Gray': 271,
#   'Mohawk Green': 255,
#   'Hat Blue': 286,
#   'Fish Green': 117,
#   'Beanie Orange': 276,
#   'Wizard Hat': 186,
#   'Sombrero': 255,
#   'Beanie Pink': 90,
#   'Cowboy Hat': 252,
#   'Headband': 357,
#   'Macaroni': 249,
#   'Party Hat': 196,
#   'Biker Helmet': 88,
#   'Viking Helmet': 196,
#   'Hat Red': 279,
#   'Hatched': 53,
#   'Mohawk Purple': 269,
#   'Bowl Cut': 89,
#   'Grizzly Bear Hat': 209,
#   'Flat Cap Tan': 274,
#   'Fish Blue': 89,
#   'Fish Gold': 22,
#   'Pirate Hat': 182,
#   'Sideways Blue': 89,
#   'Top Hat': 282,
#   'Camo Helmet': 248,
#   'Rice Hat': 89,
#   'Polar Bear Hat': 89,
#   'Egg': 89,
#   "Jester's Hat": 176,
#   'Panda Hat': 89,
#   'Crown': 58,
#   'Sideways Red': 90,
#   'Egg Gold': 45,
#   'Flower Crown': 66,
#   'Fish Orange': 44,
#   'Ice Crown': 14,
#   'Hatched Gold': 9,
#   'Pineapple Suit': 1,
#   'Banana Suit': 1,
#   'Normal': 1,
#   'Shark Suit': 1}}

# %% [markdown]
# #### All Traits

# %%
# df of all traits
# documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html
# similar to how OneHotEncoder creates new column names
traits_df_normalized = pd.json_normalize(traits_json)

traits_df_normalized
# Out:
#    Background.Beige  Background.Blue  ...  Head.Normal  Head.Shark Suit
# 0              1152             1587  ...            1                1
#
# [1 rows x 173 columns]

# %% [markdown]
# #### Isolating Traits

# %%
# show all trait keys
traits_json.keys()
# Out:
# dict_keys(['Background', 'Skin', 'Body', 'Face', 'Head'])

# %%
# explode the df
traits_df_exploded =  pd.DataFrame(traits_json)
traits_df_exploded = traits_df_exploded.explode("Background")

# create new dfs for each trait, sorted by values
# if you don't do reset_index(drop=True), it appears as a series
background_trait_df = traits_df_exploded["Background"].dropna().sort_values(ascending=False).reset_index()
skin_trait_df = traits_df_exploded["Skin"].dropna().sort_values(ascending=False).reset_index()
body_trait_df = traits_df_exploded["Body"].dropna().sort_values(ascending=False).reset_index()
face_trait_df = traits_df_exploded["Face"].dropna().sort_values(ascending=False).reset_index()
head_trait_df = traits_df_exploded["Head"].dropna().sort_values(ascending=False).reset_index()

# rename columns and set indices
background_trait_df = background_trait_df.rename(columns={"index":"background", "Background":"count"}).set_index("background")
skin_trait_df = skin_trait_df.rename(columns={"index":"skin", "Skin":"count"}).set_index("skin")
body_trait_df = body_trait_df.rename(columns={"index":"body", "Body":"count"}).set_index("body")
face_trait_df = face_trait_df.rename(columns={"index":"face", "Face":"count"}).set_index("face")
head_trait_df = head_trait_df.rename(columns={"index":"head", "Head":"count"}).set_index("head")

# display trait dataframes
display(background_trait_df, skin_trait_df, body_trait_df, face_trait_df, head_trait_df)
# Out:
#                     count
# background
# Blue               1587.0
# Mint               1389.0
# Purple             1282.0
# Beige              1152.0
# Tangerine          1135.0
# Yellow              873.0
# Red                 755.0
# Pink                710.0
# On The Beach          1.0
# Supermarket           1.0
# Green                 1.0
# Trick Or Treating     1.0
# Underwater            1.0
#                count
# skin
# Normal        2649.0
# Dark Gray     1329.0
# Light Gray    1189.0
# Maroon         731.0
# Olive Green    705.0
# Cream          646.0
# Baby Pink      623.0
# Mint           423.0
# Red            344.0
# Leopard Pink    89.0
# Leopard Gray    89.0
# Gold            44.0
# Ice             22.0
# Navy Blue        4.0
# Black            1.0
#                   count
# body
# Shirt Blue        290.0
# Kimono Brown      268.0
# Shirt Red         259.0
# Turtleneck Green  254.0
# Scarf Green       250.0
# ...                 ...
# Pineapple Suit      1.0
# Banana Suit         1.0
# Mirrored            1.0
# Pillow Case         1.0
# Shark Suit          1.0
#
# [64 rows x 1 columns]
#                 count
# face
# Winking         961.0
# Blushing        932.0
# Normal          864.0
# Circle Glasses  768.0
# Cute            588.0
# Monocle         496.0
# Squad           445.0
# Eyepatch        426.0
# Cross Eyed      417.0
# Clout Goggles   342.0
# Aviator         341.0
# Beard           320.0
# Scar            274.0
# Cucumbers       269.0
# Star Glasses    265.0
# Handlebar Bear  259.0
# Football        238.0
# Goggles         191.0
# Mustache        169.0
# Villain Mask     89.0
# Hero Mask Red    71.0
# Hero Mask Blue   71.0
# Scouter          67.0
# Star Struck      22.0
# Mirrored          1.0
# Pillow Case       1.0
# Agitated          1.0
#                     count
# head
# Headband            357.0
# Flat Cap Blue       355.0
# Bucket Hat Green    349.0
# Backwards Hat Red   294.0
# Hat Blue            286.0
# Top Hat             282.0
# Hat Red             279.0
# Beanie Orange       276.0
# Flat Cap Tan        274.0
# Beanie Gray         271.0
# Mohawk Purple       269.0
# Afro With Pick      257.0
# Sombrero            255.0
# Mohawk Green        255.0
# Cowboy Hat          252.0
# Durag Blue          252.0
# None                250.0
# Macaroni            249.0
# Camo Helmet         248.0
# Flat Cap Black      247.0
# Bucket Hat Tan      219.0
# Grizzly Bear Hat    209.0
# Santa Hat           208.0
# Viking Helmet       196.0
# Party Hat           196.0
# Wizard Hat          186.0
# Pirate Hat          182.0
# Jester's Hat        176.0
# Durag Red           174.0
# Backwards Hat Blue  173.0
# Fish Green          117.0
# Beanie Pink          90.0
# Sideways Red         90.0
# Bowl Cut             89.0
# Ninja Headband       89.0
# Fish Blue            89.0
# Sideways Blue        89.0
# Panda Hat            89.0
# Rice Hat             89.0
# Polar Bear Hat       89.0
# Egg                  89.0
# Biker Helmet         88.0
# Flower Crown         66.0
# Crown                58.0
# Hatched              53.0
# Egg Gold             45.0
# Fish Orange          44.0
# Fish Gold            22.0
# Ice Crown            14.0
# Hatched Gold          9.0
# Pineapple Suit        1.0
# Shark Suit            1.0
# Banana Suit           1.0
# Normal                1.0

# %% [markdown]
# # Data for Model

# %% [markdown]
# ## NFTs

# %%
url = "https://api.opensea.io/api/v2/collection/pudgypenguins/nfts"

headers = {
    "accept": "application/json",
    "x-api-key": opensea_api_key
}

response = requests.get(url, headers=headers)

# Formatting as json
nfts_json = response.json()

nfts_df = pd.DataFrame(nfts_json["nfts"])

# rename "name" to "asset.name" to combine dfs
nfts_df.rename(columns={"name":"asset.name"}, inplace=True)

display(nfts_df.sample(3))

display(nfts_df.columns)

display(len(nfts_df))
# Out:
#    identifier     collection  ... is_disabled is_nsfw
# 28       8828  pudgypenguins  ...       False   False
# 25       8783  pudgypenguins  ...       False   False
# 24       8784  pudgypenguins  ...        True   False
#
# [3 rows x 12 columns]
# Index(['identifier', 'collection', 'contract', 'token_standard', 'asset.name',
#        'description', 'image_url', 'metadata_url', 'opensea_url', 'updated_at',
#        'is_disabled', 'is_nsfw'],
#       dtype='object')
# 50

# %% [markdown]
# ## Sales Sample (50) "Events"

# %%
url = "https://api.opensea.io/api/v2/events/collection/pudgypenguins?event_type=sale"

headers = {
    "accept": "application/json",
    "x-api-key": opensea_api_key
}

response = requests.get(url, headers=headers)

# Formatting as json
events_json = response.json()

# get the "asset events" key and all p
events_json = events_json.get("asset_events", [])

# create df
events_df = pd.json_normalize(events_json)

# rename nft.name to asset.name
events_df.rename(columns={"nft.name":"asset.name"}, inplace=True)

display(events_df.head())

display(events_df.columns)

display(len(events_df))
# Out:
#   event_type order_hash  ... payment.decimals payment.symbol
# 0       sale             ...               18           WETH
# 1       sale             ...               18           WETH
# 2       sale             ...               18           WETH
# 3       sale             ...               18           WETH
# 4       sale             ...               18           WETH
#
# [5 rows x 26 columns]
# Index(['event_type', 'order_hash', 'chain', 'protocol_address', 'closing_date',
#        'quantity', 'seller', 'buyer', 'transaction', 'event_timestamp',
#        'nft.identifier', 'nft.collection', 'nft.contract',
#        'nft.token_standard', 'asset.name', 'nft.description', 'nft.image_url',
#        'nft.metadata_url', 'nft.opensea_url', 'nft.updated_at',
#        'nft.is_disabled', 'nft.is_nsfw', 'payment.quantity',
#        'payment.token_address', 'payment.decimals', 'payment.symbol'],
#       dtype='object')
# 50

# %% [markdown]
# ### Individual NFT Info

# %% [markdown]
# #### query parameters from https://docs.opensea.io/reference/get_nft

# %%
# PATH PARAMETERS

# note: nft contract is the same for the whole collection

# identify nft contract (public blockchain address)
# this creates an array
protocol_address = events_df["nft.contract"].unique()

# eliminate the null by getting the max of the array
protocol_address = np.max(protocol_address)

# find unique values for chain (currency)
chain = events_df["chain"].unique().tolist()

# write value without list
chain = chain[0]

# token ID in a list for iteration
token_id_list = events_df["nft.identifier"].to_list()

# %%
# parsing features function

def get_features (nft):
    features = {}
    features["Background"] = nft["traits"][0]["value"]
    features["Skin"] = nft["traits"][1]["value"]
    features["Face"] = nft["traits"][2]["value"]
    features["Head"] = nft["traits"][3]["value"]
    features["Body"] = nft["traits"][4]["value"]
    features["Rarity"] = nft["rarity"]["rank"]
    
    return features

# %%
nfts_dict = {}
token_id = token_id_list[0]

for token_id in token_id_list:
    url = f"https://api.opensea.io/api/v2/chain/{chain}/contract/{protocol_address}/nfts/{token_id}"
    headers = {
        "accept": "application/json",
        "x-api-key": "5b828d394dd74a99ad2f9142157215d2"
    }

    response = requests.get(url, headers=headers)

    # Formatting as json
    nfts_json = response.json()
    
    nfts_dict[token_id] = get_features(nfts_json["nft"])

# %%
nfts_dict

nfts_df = pd.DataFrame(nfts_dict).transpose()

nfts_df
# Out:
#               Background               Skin  ...             Body Rarity
# 1266                Blue             Normal  ...      Camo Helmet   7978
# 5277          Light Gray              Beard  ...       Cowboy Hat   3623
# 6062              Yellow              Cream  ...         Ice Coat   1231
# 8852          Fish Lover  Backwards Hat Red  ...          Monocle    917
# 8390                Blue          Santa Hat  ...       Lei Purple   8016
# 8581               Beige            Winking  ...         Macaroni   3042
# 2034                 Red    Tank Top Yellow  ...          Monocle   3068
# 5033                Mint       Bow Tie Blue  ...   Circle Glasses   4787
# 5783                Blue             Maroon  ...      Camo Helmet   1753
# 5456          Light Gray         Durag Blue  ...         Lab Coat   4046
# 5272                Mint          Dark Gray  ...            Apron   6888
# 5223          Durag Blue          Dark Gray  ...     Lei Assorted   5253
# 8780           Tangerine           Blushing  ...    Mohawk Purple   5340
# 6126               Beige         Light Gray  ...       Cowboy Hat   6165
# 7555              Normal             Normal  ...  Tribal Necklace   6987
# 8875          Light Gray                Red  ...     Jester's Hat   2379
# 4004          Light Gray               Blue  ...      Scarf Green   8178
# 8439               Beige          Dark Gray  ...      Camo Helmet   4376
# 4427  Backwards Hat Blue         Scarf Blue  ...          Monocle   2411
# 4810              Normal    Tank Top Yellow  ...          Hat Red   6257
# 7430              Normal         Durag Blue  ...    Tank Top Blue   8633
# 4376                Blue         Scarf Blue  ...         Football   7106
# 5996              Normal             Normal  ...      Camo Helmet   8098
# 8137              Purple              Cream  ...         Lab Coat   1749
# 7441          Light Gray             Yellow  ...     Jester's Hat   4136
# 3418                Blue         Fish Lover  ...   Handlebar Bear   1726
# 3372          Light Gray               Pink  ...         Hat Blue   7130
# 2773               Beige             Maroon  ...      Scarf Green   5598
# 7140                Blue             Maroon  ...   Polar Bear Hat   1346
# 799                 Blue             Normal  ...          Hat Red   8000
# 3788  Backwards Hat Blue             Normal  ...         Football   3373
# 7656                Mint          Dark Gray  ...      Scarf Green   4267
# 425                 Blue               Mint  ...   Handlebar Bear   2549
# 1167                Blue               Cute  ...   Hawaiian Shirt   4663
# 5978                Blue             Normal  ...    Flat Cap Blue   8201
# 1049          Light Gray             Normal  ...     Puffer Green   6938
# 4195             Winking               Blue  ...      Camo Helmet   8859
#
# [37 rows x 6 columns]

# %%
combined_events_df = events_df[["nft.identifier", "closing_date", "payment.quantity"]]

combined_events_df.set_index("nft.identifier", inplace=True)

combined_events_df
# Out:
#                 closing_date      payment.quantity
# nft.identifier
# 1266              1714413551  11000000000000000000
# 5277              1714413539  11000000000000000000
# 6062              1714405895  11060000000000000000
# 8852              1714405895  11060000000000000000
# 8390              1714405883  11060000000000000000
# 8581              1714405883  11060000000000000000
# 2034              1714405031  11060000000000000000
# 5033              1714405031  11060000000000000000
# 5783              1714405019  11060000000000000000
# 5456              1714404995  11060000000000000000
# 5272              1714404995  11060000000000000000
# 5223              1714404983  11060000000000000000
# 8780              1714404971  11060000000000000000
# 6126              1714404971  11060000000000000000
# 1266              1714404971  11060000000000000000
# 7555              1714404971  11060000000000000000
# 8875              1714403255  11060000000000000000
# 4004              1714403183  11060000000000000000
# 8439              1714403171  11060000000000000000
# 4427              1714403147  11080000000000000000
# 5033              1714403135  11070000000000000000
# 5033              1714400867  11150000000000000000
# 4427              1714400843  11150000000000000000
# 4810              1714400843  11150000000000000000
# 7430              1714400783  11150000000000000000
# 4376              1714400759  11160000000000000000
# 5996              1714400747  11170000000000000000
# 4004              1714400747  11170000000000000000
# 8137              1714400735  11170000000000000000
# 7441              1714398911  11200000000000000000
# 7555              1714398851  11200000000000000000
# 3418              1714390283  11060000000000000000
# 3372              1714390271  11060000000000000000
# 4376              1714390259  11070000000000000000
# 7441              1714388495  11180000000000000000
# 4427              1714376219  11100000000000000000
# 2773              1714374851  11500000000000000000
# 7140              1714374851  11130000000000000000
# 2773              1714374707  11080000000000000000
# 3418              1714374695  11070000000000000000
# 799               1714370759  11000000000000000000
# 2773              1714370747  11000000000000000000
# 3788              1714368467  10990000000000000000
# 7656              1714367999  11720000000000000000
# 425               1714367939  11910000000000000000
# 1167              1714367939  11910000000000000000
# 5978              1714367939  11910000000000000000
# 1049              1714367927  11910000000000000000
# 4195              1714367927  11910000000000000000
# 6126              1714367915  11910000000000000000

# %%
combined_df = combined_events_df.merge(nfts_df, how="outer", right_index=True, left_index=True)

combined_df
# Out:
#                 closing_date      payment.quantity  ...             Body Rarity
# nft.identifier                                      ...
# 1049              1714367927  11910000000000000000  ...     Puffer Green   6938
# 1167              1714367939  11910000000000000000  ...   Hawaiian Shirt   4663
# 1266              1714413551  11000000000000000000  ...      Camo Helmet   7978
# 1266              1714404971  11060000000000000000  ...      Camo Helmet   7978
# 2034              1714405031  11060000000000000000  ...          Monocle   3068
# 2773              1714374851  11500000000000000000  ...      Scarf Green   5598
# 2773              1714374707  11080000000000000000  ...      Scarf Green   5598
# 2773              1714370747  11000000000000000000  ...      Scarf Green   5598
# 3372              1714390271  11060000000000000000  ...         Hat Blue   7130
# 3418              1714390283  11060000000000000000  ...   Handlebar Bear   1726
# 3418              1714374695  11070000000000000000  ...   Handlebar Bear   1726
# 3788              1714368467  10990000000000000000  ...         Football   3373
# 4004              1714403183  11060000000000000000  ...      Scarf Green   8178
# 4004              1714400747  11170000000000000000  ...      Scarf Green   8178
# 4195              1714367927  11910000000000000000  ...      Camo Helmet   8859
# 425               1714367939  11910000000000000000  ...   Handlebar Bear   2549
# 4376              1714400759  11160000000000000000  ...         Football   7106
# 4376              1714390259  11070000000000000000  ...         Football   7106
# 4427              1714403147  11080000000000000000  ...          Monocle   2411
# 4427              1714400843  11150000000000000000  ...          Monocle   2411
# 4427              1714376219  11100000000000000000  ...          Monocle   2411
# 4810              1714400843  11150000000000000000  ...          Hat Red   6257
# 5033              1714405031  11060000000000000000  ...   Circle Glasses   4787
# 5033              1714403135  11070000000000000000  ...   Circle Glasses   4787
# 5033              1714400867  11150000000000000000  ...   Circle Glasses   4787
# 5223              1714404983  11060000000000000000  ...     Lei Assorted   5253
# 5272              1714404995  11060000000000000000  ...            Apron   6888
# 5277              1714413539  11000000000000000000  ...       Cowboy Hat   3623
# 5456              1714404995  11060000000000000000  ...         Lab Coat   4046
# 5783              1714405019  11060000000000000000  ...      Camo Helmet   1753
# 5978              1714367939  11910000000000000000  ...    Flat Cap Blue   8201
# 5996              1714400747  11170000000000000000  ...      Camo Helmet   8098
# 6062              1714405895  11060000000000000000  ...         Ice Coat   1231
# 6126              1714404971  11060000000000000000  ...       Cowboy Hat   6165
# 6126              1714367915  11910000000000000000  ...       Cowboy Hat   6165
# 7140              1714374851  11130000000000000000  ...   Polar Bear Hat   1346
# 7430              1714400783  11150000000000000000  ...    Tank Top Blue   8633
# 7441              1714398911  11200000000000000000  ...     Jester's Hat   4136
# 7441              1714388495  11180000000000000000  ...     Jester's Hat   4136
# 7555              1714404971  11060000000000000000  ...  Tribal Necklace   6987
# 7555              1714398851  11200000000000000000  ...  Tribal Necklace   6987
# 7656              1714367999  11720000000000000000  ...      Scarf Green   4267
# 799               1714370759  11000000000000000000  ...          Hat Red   8000
# 8137              1714400735  11170000000000000000  ...         Lab Coat   1749
# 8390              1714405883  11060000000000000000  ...       Lei Purple   8016
# 8439              1714403171  11060000000000000000  ...      Camo Helmet   4376
# 8581              1714405883  11060000000000000000  ...         Macaroni   3042
# 8780              1714404971  11060000000000000000  ...    Mohawk Purple   5340
# 8852              1714405895  11060000000000000000  ...          Monocle    917
# 8875              1714403255  11060000000000000000  ...     Jester's Hat   2379
#
# [50 rows x 8 columns]

# %%
combined_df.to_csv("mariamaria4.25.2024")

# %%
def convert_usd_to_eth(usd_amount):
    # API URL for getting the latest ETH price in USD
    url = "https://api.coingecko.com/api/v3/simple/price?ids=ethereum&vs_currencies=usd"
    
    try:
        response = requests.get(url)
        data = response.json()
        
        # Getting the current price of 1 ETH in USD
        eth_price = data['ethereum']['usd']
        
        # Calculating the amount in ETH
        eth_amount = usd_amount / eth_price
        
        return eth_amount
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Example: Convert 100 USD to ETH
usd_amount = 100
eth_amount = convert_usd_to_eth(usd_amount)
eth_amount
# Out:
# An error occurred: name 'requests' is not defined
