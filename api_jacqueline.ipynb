# %%
import requests
import pandas as pd
import os
from dotenv import load_dotenv
import json
import numpy as np

# %%
load_dotenv()
opensea_api_key = os.getenv('OPENSEA_API_KEY')

# %% [markdown]
# # Data for Context and Analysis

# %% [markdown]
# ### Collection Stats

# %%
url = "https://api.opensea.io/api/v2/collections/pudgypenguins/stats"

headers = {
    "accept": "application/json",
    "x-api-key": opensea_api_key
}

response = requests.get(url, headers=headers)

collection_stats_response_json = response.json()

collection_totals_dict = collection_stats_response_json["total"]

# I had to set this index because there is not index and it was causing an error
# I used ChatGPT to debug this issue
collection_totals_df = pd.DataFrame(collection_totals_dict, index=[0])

collection_totals_df
# Out:
#          volume  sales  average_price  num_owners    market_cap  floor_price  \
# 0  343690.47517  78770       4.363215        4763  92617.799483       13.175
#
#   floor_price_symbol
# 0                ETH

# %% [markdown]
# ## Trait Counts

# %%
url = "https://api.opensea.io/api/v2/traits/pudgypenguins"

headers = {
    "accept": "application/json",
    "x-api-key": opensea_api_key
}

response = requests.get(url, headers=headers)

# Formatting as json
traits_json = response.json()

# get the "counts" and not "categories" key
traits_json = traits_json.get("counts", [])

# preview
traits_json
# Out:
# {'Background': {'Beige': 1152,
#   'Blue': 1587,
#   'Mint': 1389,
#   'Red': 755,
#   'Tangerine': 1135,
#   'Yellow': 873,
#   'Pink': 710,
#   'Purple': 1282,
#   'On The Beach': 1,
#   'Supermarket': 1,
#   'Green': 1,
#   'Trick Or Treating': 1,
#   'Underwater': 1},
#  'Skin': {'Light Gray': 1189,
#   'Mint': 423,
#   'Maroon': 731,
#   'Normal': 2649,
#   'Leopard Pink': 89,
#   'Dark Gray': 1329,
#   'Baby Pink': 623,
#   'Cream': 646,
#   'Olive Green': 705,
#   'Red': 344,
#   'Gold': 44,
#   'Leopard Gray': 89,
#   'Ice': 22,
#   'Navy Blue': 4,
#   'Black': 1},
#  'Body': {'Vote 4 Pudgy': 203,
#   'Kimono Blue': 108,
#   'Scarf Blue': 237,
#   'Shirt Blue': 290,
#   'Fish Lover': 70,
#   'Turtleneck Grey': 210,
#   'Lei Pink': 168,
#   'Bow Tie Blue': 154,
#   'Tank Top Yellow': 193,
#   'Puffer Orange': 158,
#   'Huddle Shirt': 228,
#   'Kimono Brown': 268,
#   'Lei Assorted': 76,
#   'Bronze Medal': 193,
#   'Gold Medal': 58,
#   'Heart': 102,
#   'Turtleneck Green': 254,
#   'Scarf Pink': 177,
#   'Surfboard Necklace': 166,
#   'Swordman': 62,
#   'Christmas Sweater Red': 89,
#   'Bath Robe': 246,
#   'Turtleneck Blue': 238,
#   'Hoodie Black': 183,
#   'Silver Medal': 141,
#   'Puffer Green': 167,
#   'Shirt Red': 259,
#   'Kimono Orange': 115,
#   'Christmas Lights': 131,
#   'Turtleneck Pink': 182,
#   'Suit Blue': 89,
#   'Bow Tie Pink': 172,
#   'Tribal Necklace': 115,
#   'Overalls': 171,
#   'Bow Tie Black': 193,
#   'Scarf Green': 250,
#   'Lei Blue': 180,
#   'Kimono White': 89,
#   'Christmas Sweater Blue': 89,
#   'Kimono Red': 169,
#   'Tank Top Blue': 202,
#   'Puffer Blue': 158,
#   'Kimono Gold': 44,
#   'Biker Jacket': 67,
#   'Apron': 199,
#   'Lei Purple': 186,
#   'Lab Coat': 227,
#   'Shark Tooth Necklace': 88,
#   'Hawaiian Shirt': 171,
#   'Suit Red': 78,
#   'Ice Coat': 123,
#   'Kimono Pink': 89,
#   'Hoodie Pink': 162,
#   'Big P': 71,
#   'Kimono Abstract': 53,
#   'Crop Top': 89,
#   'Kimono Ice': 22,
#   'Pudgy Man': 44,
#   'Pineapple Suit': 1,
#   'Poncho': 167,
#   'Banana Suit': 1,
#   'Mirrored': 1,
#   'Pillow Case': 1,
#   'Shark Suit': 1},
#  'Face': {'Winking': 961,
#   'Star Glasses': 265,
#   'Normal': 864,
#   'Cute': 588,
#   'Beard': 320,
#   'Hero Mask Red': 71,
#   'Scar': 274,
#   'Blushing': 932,
#   'Eyepatch': 426,
#   'Clout Goggles': 342,
#   'Squad': 445,
#   'Circle Glasses': 768,
#   'Goggles': 191,
#   'Aviator': 341,
#   'Villain Mask': 89,
#   'Cross Eyed': 417,
#   'Football': 238,
#   'Mustache': 169,
#   'Cucumbers': 269,
#   'Monocle': 496,
#   'Handlebar Bear': 259,
#   'Scouter': 67,
#   'Hero Mask Blue': 71,
#   'Star Struck': 22,
#   'Mirrored': 1,
#   'Pillow Case': 1,
#   'Agitated': 1},
#  'Head': {'Backwards Hat Blue': 173,
#   'Bucket Hat Tan': 219,
#   'Santa Hat': 208,
#   'Durag Blue': 252,
#   'Backwards Hat Red': 294,
#   'Durag Red': 174,
#   'None': 250,
#   'Ninja Headband': 89,
#   'Afro With Pick': 257,
#   'Bucket Hat Green': 349,
#   'Flat Cap Black': 247,
#   'Flat Cap Blue': 355,
#   'Beanie Gray': 271,
#   'Mohawk Green': 255,
#   'Hat Blue': 286,
#   'Fish Green': 117,
#   'Beanie Orange': 276,
#   'Wizard Hat': 186,
#   'Sombrero': 255,
#   'Beanie Pink': 90,
#   'Cowboy Hat': 252,
#   'Headband': 357,
#   'Macaroni': 249,
#   'Party Hat': 196,
#   'Biker Helmet': 88,
#   'Viking Helmet': 196,
#   'Hat Red': 279,
#   'Hatched': 53,
#   'Mohawk Purple': 269,
#   'Bowl Cut': 89,
#   'Grizzly Bear Hat': 209,
#   'Flat Cap Tan': 274,
#   'Fish Blue': 89,
#   'Fish Gold': 22,
#   'Pirate Hat': 182,
#   'Sideways Blue': 89,
#   'Top Hat': 282,
#   'Camo Helmet': 248,
#   'Rice Hat': 89,
#   'Polar Bear Hat': 89,
#   'Egg': 89,
#   "Jester's Hat": 176,
#   'Panda Hat': 89,
#   'Crown': 58,
#   'Sideways Red': 90,
#   'Egg Gold': 45,
#   'Flower Crown': 66,
#   'Fish Orange': 44,
#   'Ice Crown': 14,
#   'Hatched Gold': 9,
#   'Pineapple Suit': 1,
#   'Banana Suit': 1,
#   'Normal': 1,
#   'Shark Suit': 1}}

# %% [markdown]
# #### All Traits

# %%
# df of all traits
# documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html
# similar to how OneHotEncoder creates new column names
traits_df_normalized = pd.json_normalize(traits_json)

traits_df_normalized
# Out:
#    Background.Beige  Background.Blue  Background.Mint  Background.Red  \
# 0              1152             1587             1389             755
#
#    Background.Tangerine  Background.Yellow  Background.Pink  \
# 0                  1135                873              710
#
#    Background.Purple  Background.On The Beach  Background.Supermarket  ...  \
# 0               1282                        1                       1  ...
#
#    Head.Sideways Red  Head.Egg Gold  Head.Flower Crown  Head.Fish Orange  \
# 0                 90             45                 66                44
#
#    Head.Ice Crown  Head.Hatched Gold  Head.Pineapple Suit  Head.Banana Suit  \
# 0              14                  9                    1                 1
#
#    Head.Normal  Head.Shark Suit
# 0            1                1
#
# [1 rows x 173 columns]

# %% [markdown]
# #### Isolating Traits

# %%
# show all trait keys
traits_json.keys()
# Out:
# dict_keys(['Background', 'Skin', 'Body', 'Face', 'Head'])

# %%
# explode the df
traits_df_exploded =  pd.DataFrame(traits_json)
traits_df_exploded = traits_df_exploded.explode("Background")

# create new dfs for each trait, sorted by values
# if you don't do reset_index(drop=True), it appears as a series
background_trait_df = traits_df_exploded["Background"].dropna().sort_values(ascending=False).reset_index()
skin_trait_df = traits_df_exploded["Skin"].dropna().sort_values(ascending=False).reset_index()
body_trait_df = traits_df_exploded["Body"].dropna().sort_values(ascending=False).reset_index()
face_trait_df = traits_df_exploded["Face"].dropna().sort_values(ascending=False).reset_index()
head_trait_df = traits_df_exploded["Head"].dropna().sort_values(ascending=False).reset_index()

# rename columns and set indices
background_trait_df = background_trait_df.rename(columns={"index":"background", "Background":"count"}).set_index("background")
skin_trait_df = skin_trait_df.rename(columns={"index":"skin", "Skin":"count"}).set_index("skin")
body_trait_df = body_trait_df.rename(columns={"index":"body", "Body":"count"}).set_index("body")
face_trait_df = face_trait_df.rename(columns={"index":"face", "Face":"count"}).set_index("face")
head_trait_df = head_trait_df.rename(columns={"index":"head", "Head":"count"}).set_index("head")

# display trait dataframes
display(background_trait_df, skin_trait_df, body_trait_df, face_trait_df, head_trait_df)
# Out:
#                     count
# background
# Blue               1587.0
# Mint               1389.0
# Purple             1282.0
# Beige              1152.0
# Tangerine          1135.0
# Yellow              873.0
# Red                 755.0
# Pink                710.0
# On The Beach          1.0
# Supermarket           1.0
# Green                 1.0
# Trick Or Treating     1.0
# Underwater            1.0
#                count
# skin
# Normal        2649.0
# Dark Gray     1329.0
# Light Gray    1189.0
# Maroon         731.0
# Olive Green    705.0
# Cream          646.0
# Baby Pink      623.0
# Mint           423.0
# Red            344.0
# Leopard Pink    89.0
# Leopard Gray    89.0
# Gold            44.0
# Ice             22.0
# Navy Blue        4.0
# Black            1.0
#                   count
# body
# Shirt Blue        290.0
# Kimono Brown      268.0
# Shirt Red         259.0
# Turtleneck Green  254.0
# Scarf Green       250.0
# ...                 ...
# Pineapple Suit      1.0
# Banana Suit         1.0
# Mirrored            1.0
# Pillow Case         1.0
# Shark Suit          1.0
#
# [64 rows x 1 columns]
#                 count
# face
# Winking         961.0
# Blushing        932.0
# Normal          864.0
# Circle Glasses  768.0
# Cute            588.0
# Monocle         496.0
# Squad           445.0
# Eyepatch        426.0
# Cross Eyed      417.0
# Clout Goggles   342.0
# Aviator         341.0
# Beard           320.0
# Scar            274.0
# Cucumbers       269.0
# Star Glasses    265.0
# Handlebar Bear  259.0
# Football        238.0
# Goggles         191.0
# Mustache        169.0
# Villain Mask     89.0
# Hero Mask Red    71.0
# Hero Mask Blue   71.0
# Scouter          67.0
# Star Struck      22.0
# Mirrored          1.0
# Pillow Case       1.0
# Agitated          1.0
#                     count
# head
# Headband            357.0
# Flat Cap Blue       355.0
# Bucket Hat Green    349.0
# Backwards Hat Red   294.0
# Hat Blue            286.0
# Top Hat             282.0
# Hat Red             279.0
# Beanie Orange       276.0
# Flat Cap Tan        274.0
# Beanie Gray         271.0
# Mohawk Purple       269.0
# Afro With Pick      257.0
# Sombrero            255.0
# Mohawk Green        255.0
# Cowboy Hat          252.0
# Durag Blue          252.0
# None                250.0
# Macaroni            249.0
# Camo Helmet         248.0
# Flat Cap Black      247.0
# Bucket Hat Tan      219.0
# Grizzly Bear Hat    209.0
# Santa Hat           208.0
# Viking Helmet       196.0
# Party Hat           196.0
# Wizard Hat          186.0
# Pirate Hat          182.0
# Jester's Hat        176.0
# Durag Red           174.0
# Backwards Hat Blue  173.0
# Fish Green          117.0
# Beanie Pink          90.0
# Sideways Red         90.0
# Bowl Cut             89.0
# Ninja Headband       89.0
# Fish Blue            89.0
# Sideways Blue        89.0
# Panda Hat            89.0
# Rice Hat             89.0
# Polar Bear Hat       89.0
# Egg                  89.0
# Biker Helmet         88.0
# Flower Crown         66.0
# Crown                58.0
# Hatched              53.0
# Egg Gold             45.0
# Fish Orange          44.0
# Fish Gold            22.0
# Ice Crown            14.0
# Hatched Gold          9.0
# Pineapple Suit        1.0
# Shark Suit            1.0
# Banana Suit           1.0
# Normal                1.0

# %% [markdown]
# # Data for Model

# %% [markdown]
# ## NFTs

# %%
url = "https://api.opensea.io/api/v2/collection/pudgypenguins/nfts"

headers = {
    "accept": "application/json",
    "x-api-key": opensea_api_key
}

response = requests.get(url, headers=headers)

# Formatting as json
nfts_json = response.json()

nfts_df = pd.DataFrame(nfts_json["nfts"])

# rename "name" to "asset.name" to combine dfs
nfts_df.rename(columns={"name":"asset.name"}, inplace=True)

display(nfts_df.sample(3))

display(nfts_df.columns)

display(len(nfts_df))
# Out:
#    identifier     collection                                    contract  \
# 28       8828  pudgypenguins  0xbd3531da5cf5857e7cfaa92426877b022e612cf8
# 40       8859  pudgypenguins  0xbd3531da5cf5857e7cfaa92426877b022e612cf8
# 14       8876  pudgypenguins  0xbd3531da5cf5857e7cfaa92426877b022e612cf8
#
#    token_standard           asset.name  \
# 28         erc721  Pudgy Penguin #8828
# 40         erc721  Pudgy Penguin #8859
# 14         erc721  Pudgy Penguin #8876
#
#                                           description  \
# 28  A collection 8888 Cute Chubby Pudgy Penquins s...
# 40  A collection 8888 Cute Chubby Pudgy Penquins s...
# 14  A collection 8888 Cute Chubby Pudgy Penquins s...
#
#                                             image_url  \
# 28  https://ipfs.io/ipfs/QmNf1UsmdGaMbpatQ6toXSkzD...
# 40  https://ipfs.io/ipfs/QmNf1UsmdGaMbpatQ6toXSkzD...
# 14  https://ipfs.io/ipfs/QmNf1UsmdGaMbpatQ6toXSkzD...
#
#                                          metadata_url  \
# 28  https://ipfs.io/ipfs/bafybeibc5sgo2plmjkq2tzmh...
# 40  https://ipfs.io/ipfs/bafybeibc5sgo2plmjkq2tzmh...
# 14  https://ipfs.io/ipfs/bafybeibc5sgo2plmjkq2tzmh...
#
#                                           opensea_url  \
# 28  https://opensea.io/assets/ethereum/0xbd3531da5...
# 40  https://opensea.io/assets/ethereum/0xbd3531da5...
# 14  https://opensea.io/assets/ethereum/0xbd3531da5...
#
#                     updated_at  is_disabled  is_nsfw
# 28  2023-07-26T20:09:57.859296        False    False
# 40  2024-04-01T00:22:02.321751        False    False
# 14  2023-07-26T20:11:40.224767        False    False
# Index(['identifier', 'collection', 'contract', 'token_standard', 'asset.name',
#        'description', 'image_url', 'metadata_url', 'opensea_url', 'updated_at',
#        'is_disabled', 'is_nsfw'],
#       dtype='object')
# 50

# %% [markdown]
# ## Sales Sample (50) "Events"

# %%
url = "https://api.opensea.io/api/v2/events/collection/pudgypenguins?event_type=sale"

headers = {
    "accept": "application/json",
    "x-api-key": opensea_api_key
}

response = requests.get(url, headers=headers)

# Formatting as json
events_json = response.json()

# get the "asset events" key and all p
events_json = events_json.get("asset_events", [])

# create df
events_df = pd.json_normalize(events_json)

# rename nft.name to asset.name
events_df.rename(columns={"nft.name":"asset.name"}, inplace=True)

display(events_df.head())

display(events_df.columns)

display(len(events_df))
# Out:
#   event_type                                         order_hash     chain  \
# 0       sale  0x2f423051b75ade3673b75fba44a1c934fae6d27f816d...  ethereum
# 1       sale                                                     ethereum
# 2       sale  0x041251e52c4dbd0a4b55347649fd2e60f56572415e07...  ethereum
# 3       sale                                                     ethereum
# 4       sale                                                     ethereum
#
#                              protocol_address  closing_date  quantity  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1714075583         1
# 1                                                1714073603         1
# 2  0x0000000000000068f116a894984e2db1123eb395    1714067747         1
# 3                                                1714067723         1
# 4                                                1714058999         1
#
#                                        seller  \
# 0  0x2ebb3cf9d35e5a69419b9c9a7764f2fa4fe2b930
# 1  0x29469395eaf6f95920e59f858042f0e28d98a20b
# 2  0x24f1fce2f3742fb9895fe672994fbec949241f1d
# 3  0xac32967007909f5b312557e4909cb73a3dea3d8d
# 4  0x29469395eaf6f95920e59f858042f0e28d98a20b
#
#                                         buyer  \
# 0  0xcae2ff6837ec6c8690675b5f1e619c04a77f3114
# 1  0x218e312ff5181290a46e3f87a73a8ad40c05a944
# 2  0xac32967007909f5b312557e4909cb73a3dea3d8d
# 3  0x29469395eaf6f95920e59f858042f0e28d98a20b
# 4  0x13747adca0ce7e7f6aa661718a07e4c74e62ed19
#
#                                          transaction  event_timestamp  ...  \
# 0  0x0eab7f5e06c9214fb782f39a04bd55fd564e170b1b94...       1714075583  ...
# 1  0x9a6b3aef1920c07cd61da8ad7895a5f4932e33df5cb3...       1714073603  ...
# 2  0xff5de2a81422c58530c593d7f7f2e5b61fd0ca3210ea...       1714067747  ...
# 3  0x3f1784b1e73138ca38a04955bb6d6f7be2aec7fa49ab...       1714067723  ...
# 4  0x4d549d05db59caa63f69bd2171ad88a3b68d119d11af...       1714058999  ...
#
#                                        nft.image_url  \
# 0  https://ipfs.io/ipfs/QmNf1UsmdGaMbpatQ6toXSkzD...
# 1  https://ipfs.io/ipfs/QmNf1UsmdGaMbpatQ6toXSkzD...
# 2  https://ipfs.io/ipfs/QmNf1UsmdGaMbpatQ6toXSkzD...
# 3  https://ipfs.io/ipfs/QmNf1UsmdGaMbpatQ6toXSkzD...
# 4  https://ipfs.io/ipfs/QmNf1UsmdGaMbpatQ6toXSkzD...
#
#                                     nft.metadata_url  \
# 0  https://ipfs.io/ipfs/bafybeibc5sgo2plmjkq2tzmh...
# 1  https://ipfs.io/ipfs/bafybeibc5sgo2plmjkq2tzmh...
# 2  https://ipfs.io/ipfs/bafybeibc5sgo2plmjkq2tzmh...
# 3  https://ipfs.io/ipfs/bafybeibc5sgo2plmjkq2tzmh...
# 4  https://ipfs.io/ipfs/bafybeibc5sgo2plmjkq2tzmh...
#
#                                      nft.opensea_url  \
# 0  https://opensea.io/assets/ethereum/0xbd3531da5...
# 1  https://opensea.io/assets/ethereum/0xbd3531da5...
# 2  https://opensea.io/assets/ethereum/0xbd3531da5...
# 3  https://opensea.io/assets/ethereum/0xbd3531da5...
# 4  https://opensea.io/assets/ethereum/0xbd3531da5...
#
#                nft.updated_at nft.is_disabled nft.is_nsfw  \
# 0  2024-04-25T20:06:25.873055           False       False
# 1  2024-04-25T19:33:25.760992           False       False
# 2  2024-04-25T17:55:49.350564           False       False
# 3  2024-04-25T17:55:26.298519           False       False
# 4  2024-04-25T15:30:03.434971           False       False
#
#        payment.quantity                       payment.token_address  \
# 0  13690000000000000000  0x0000000000000000000000000000000000000000
# 1  12250000000000000000  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2  12960000000000000000  0x0000000000000000000000000000000000000000
# 3  12361800000000000000  0x0000000000000000000000000000000000000000
# 4  11400000000000000000  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#   payment.decimals payment.symbol
# 0               18            ETH
# 1               18           WETH
# 2               18            ETH
# 3               18            ETH
# 4               18           WETH
#
# [5 rows x 26 columns]
# Index(['event_type', 'order_hash', 'chain', 'protocol_address', 'closing_date',
#        'quantity', 'seller', 'buyer', 'transaction', 'event_timestamp',
#        'nft.identifier', 'nft.collection', 'nft.contract',
#        'nft.token_standard', 'asset.name', 'nft.description', 'nft.image_url',
#        'nft.metadata_url', 'nft.opensea_url', 'nft.updated_at',
#        'nft.is_disabled', 'nft.is_nsfw', 'payment.quantity',
#        'payment.token_address', 'payment.decimals', 'payment.symbol'],
#       dtype='object')
# 50

# %% [markdown]
# ### Individual NFT Info

# %% [markdown]
# #### query parameters from https://docs.opensea.io/reference/get_nft

# %%
# PATH PARAMETERS

# note: nft contract is the same for the whole collection

# identify nft contract (public blockchain address)
# this creates an array
protocol_address = events_df["nft.contract"].unique()

# eliminate the null by getting the max of the array
protocol_address = np.max(protocol_address)

# find unique values for chain (currency)
chain = events_df["chain"].unique().tolist()

# write value without list
chain = chain[0]

# token ID in a list for iteration
token_id_list = events_df["nft.identifier"].to_list()

# %%
# parsing features function

def get_features (nft):
    features = {}
    features["Background"] = nft["traits"][0]["value"]
    features["Skin"] = nft["traits"][1]["value"]
    features["Face"] = nft["traits"][2]["value"]
    features["Head"] = nft["traits"][3]["value"]
    features["Body"] = nft["traits"][4]["value"]
    features["Rarity"] = nft["rarity"]["rank"]
    
    return features

# %%
nfts_dict = {}
token_id = token_id_list[0]

for token_id in token_id_list:
    url = f"https://api.opensea.io/api/v2/chain/{chain}/contract/{protocol_address}/nfts/{token_id}"
    headers = {
        "accept": "application/json",
        "x-api-key": "5b828d394dd74a99ad2f9142157215d2"
    }

    response = requests.get(url, headers=headers)

    # Formatting as json
    nfts_json = response.json()
    
    nfts_dict[token_id] = get_features(nfts_json["nft"])

# %%
nfts_dict

nfts_df = pd.DataFrame(nfts_dict).transpose()

nfts_df
# Out:
#       Background            Skin               Face               Head  \
# 4549   Baby Pink        Blushing             Purple    Turtleneck Blue
# 2689   Baby Pink          Purple           Sombrero         Cross Eyed
# 5490      Maroon      Scarf Blue          Tangerine          Cucumbers
# 4251       Beige          Normal    Tank Top Yellow      Flat Cap Blue
# 5968      Normal            Cute  Backwards Hat Red             Purple
# 563         Mint       Dark Gray       Huddle Shirt           Blushing
# 4436  Light Gray          Purple      Bow Tie Black            Hat Red
# 3114  Light Gray           Beard             Purple   Turtleneck Green
# 8390        Blue       Santa Hat             Normal               Cute
# 5996      Normal          Normal               Pink        Scarf Green
# 151   Light Gray  Afro With Pick             Purple     Circle Glasses
# 7142       Beige          Normal       Mohawk Green        Olive Green
# 6644       Beige          Maroon             Normal          Santa Hat
# 3852      Normal       Tangerine           Eyepatch           Overalls
# 2875     Winking            Blue          Baby Pink       Huddle Shirt
# 1496      Normal            Mint              Cream       Flat Cap Tan
# 8413      Normal             Red     Circle Glasses           Overalls
# 5074  Light Gray          Normal               Pink         Scarf Pink
# 2834        Mint          Normal        Beanie Gray      Kimono Orange
# 7765       Beige            Mint     Flat Cap Black      Clout Goggles
# 3245      Purple           Squad        Olive Green           Headband
# 8104       Beige         Winking          Dark Gray     Afro With Pick
# 2132        Blue          Normal             Normal    Turtleneck Blue
# 6640  Light Gray       Tangerine    Turtleneck Grey         Cowboy Hat
# 8834      Normal          Normal             Purple    Turtleneck Blue
# 6881        Blue           Cream      Clout Goggles           Hat Blue
# 753      Winking          Normal               Pink        Beanie Gray
# 7656        Mint       Dark Gray            Goggles           Macaroni
# 1569   Baby Pink          Purple     Circle Glasses      Mohawk Purple
# 6079       Beige      Light Gray             Normal  Backwards Hat Red
#
#                     Body Rarity
# 4549            Bowl Cut   3351
# 2689            Lab Coat   3913
# 5490             Hat Red   3155
# 4251               Cream   6296
# 5968  Surfboard Necklace   8045
# 563       Afro With Pick   8099
# 4436      Handlebar Bear   4176
# 3114            Headband   6306
# 8390          Lei Purple   8016
# 5996         Camo Helmet   8098
# 151                Apron   7113
# 7142           Bath Robe   6294
# 6644      Hawaiian Shirt   4748
# 3852    Grizzly Bear Hat   6416
# 2875         Camo Helmet   6853
# 1496            Lab Coat   6564
# 8413           Party Hat   6734
# 5074            Hat Blue   5809
# 2834        Villain Mask   2223
# 7765              Poncho   1470
# 3245         Scarf Green   5729
# 8104        Hoodie Black   7428
# 2132        Flat Cap Tan   8835
# 6640          Cross Eyed   5169
# 8834           Party Hat   8475
# 6881      Hawaiian Shirt   3595
# 753         Silver Medal   7420
# 7656         Scarf Green   4267
# 1569              Poncho   4943
# 6079            Swordman   4218
